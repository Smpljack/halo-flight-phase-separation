# %%
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
from datetime import datetime, timedelta
import sys
sys.path.append("/Users/lutz/halo-flight-phase-separation/")

#from typhon.plots import worldmap
import FlightPhaseTools as fpt
from ResearchFlight import ResearchFlight
from ResearchFlightSegment import ResearchFlightSegment

# %% [markdown]
# # Load data into xarray datasets using typhon FileSet objects.

# %%
bahamas = xr.open_dataset('/Users/lutz/dataE/bahamas_20200213_v0.4.nc')
dropsondes = xr.open_dataset('/Users/lutz/dataE/dropsondes_20200213_v0.4.nc')

# %% [markdown]
# # Determine the timestamps of the different flight phases using the FlightPhaseTools module.

# %%
takeoff = 0
touchdown = len(bahamas['time']) - 1

#1st circle set
###############


enter_c1_ds = fpt.ds_timestamp_ind(bahamas, dropsondes, 0)
enter_c1 = fpt.timestamp_ind_1min_prior(bahamas, enter_c1_ds)
exit_c1 = fpt.exit_circle_timestamp_ind(bahamas, enter_c1)
#enter_c1 = fpt.ds_timestamp_ind(bahamas, dropsondes,  0)
#exit_c1  = fpt.ds_timestamp_ind(bahamas, dropsondes, 12)
print ('c1')
print ('----')
print (bahamas.heading[enter_c1])
print ('----')
print (exit_c1)
print (bahamas.heading[exit_c1])
print ('----')
exit_c1 = 4769
print (exit_c1)
print (bahamas.heading[exit_c1])
print ('----')

enter_c2_ds = fpt.ds_timestamp_ind(bahamas, dropsondes, 13)
enter_c2 = fpt.timestamp_ind_1min_prior(bahamas, enter_c2_ds) 
exit_c2 = fpt.exit_circle_timestamp_ind(bahamas, enter_c2)
#enter_c2 = fpt.ds_timestamp_ind(bahamas, dropsondes, 13)
#exit_c2  = fpt.ds_timestamp_ind(bahamas, dropsondes, 23)
print ('c2')
print ('----')
print (bahamas.heading[enter_c2])
print ('----')
print (exit_c2)
print (bahamas.heading[exit_c2])
print ('----')
exit_c2 = 8937
print (exit_c2)
print (bahamas.heading[exit_c2])
print ('----')

enter_c3_ds = fpt.ds_timestamp_ind(bahamas, dropsondes, 24)
enter_c3 = fpt.timestamp_ind_1min_prior(bahamas, enter_c3_ds) 
exit_c3 = fpt.exit_circle_timestamp_ind(bahamas, enter_c3)
#enter_c3 = fpt.ds_timestamp_ind(bahamas, dropsondes, 24)
#exit_c3  = fpt.ds_timestamp_ind(bahamas, dropsondes, 35)
print ('c3')
print ('----')
print (bahamas.heading[enter_c3])
print ('----')
print (exit_c3)
print (bahamas.heading[exit_c3])
print ('----')
exit_c3 = 12894
print (exit_c3)
print (bahamas.heading[exit_c3])
print ('----')
headingdiff_c3 = bahamas['heading'][exit_c3]-bahamas['heading'][enter_c3]+360


#leg1 (towards NTAS)
min_roll_before_leg1 = fpt.min_timestamp_ind(bahamas, 'roll', 
                       slice('2020-02-13T11:30:00', '2020-02-13T11:45:00'), order=1000)

enter_leg1 = fpt.find_first_value_after_ts_ind(bahamas, 'roll', min_roll_before_leg1, 0., 0.05) - 38

min_roll_after_leg1 = fpt.min_timestamp_ind(bahamas, 'roll', 
                      slice('2020-02-13T12:00:00', '2020-02-13T12:15:00'), order=1000)

exit_leg1 = fpt.find_first_value_before_ts_ind(bahamas, 'roll', min_roll_after_leg1, 0., 0.01) + 2

#radar_cal_wiggle
max_roll_before_radar_cal_wiggle = fpt.max_timestamp_ind(bahamas, 'roll',
                                   slice('2020-02-13T12:00:00', '2020-02-13T12:20:00'), order=1000)

enter_radar_cal_wiggle = fpt.find_first_value_after_ts_ind(bahamas, 'roll', max_roll_before_radar_cal_wiggle, 0., 0.3)
exit_radar_cal_wiggle = 15458

#leg2 (return NTAS)
min_roll_before_leg2 = fpt.min_timestamp_ind(bahamas, 'roll', 
                       slice('2020-02-13T12:10:00', '2020-02-13T12:30:00'), order=1000)

enter_leg2 = fpt.find_first_value_after_ts_ind(bahamas, 'roll', min_roll_before_leg2, 0., 0.05) - 35

min_roll_after_leg2 = fpt.min_timestamp_ind(bahamas, 'roll', 
                      slice('2020-02-13T12:50:00', '2020-02-13T12:59:00'), order=1000) 

exit_leg2 = fpt.find_first_value_before_ts_ind(bahamas, 'roll', min_roll_after_leg2, 0., 0.05) + 22

#2nd circle set
###############
enter_c4_ds = fpt.ds_timestamp_ind(bahamas, dropsondes, 37)
enter_c4 = fpt.timestamp_ind_1min_prior(bahamas, enter_c4_ds)
#exit_c4 = fpt.exit_circle_timestamp_ind(bahamas, enter_c4)
#enter_c4 = fpt.ds_timestamp_ind(bahamas, dropsondes, 37)
exit_c4  = fpt.ds_timestamp_ind(bahamas, dropsondes, 48)
print ('c4')
print ('----')
print (bahamas.heading[enter_c4])
print ('----')
print (exit_c4)
print (bahamas.heading[exit_c4])
print ('----')
exit_c4 = 22000
print (exit_c4)
print (bahamas.heading[exit_c4])
print ('----')

enter_c5_ds = fpt.ds_timestamp_ind(bahamas, dropsondes, 49)
enter_c5 = fpt.timestamp_ind_1min_prior(bahamas, enter_c5_ds)
#exit_c5 = fpt.exit_circle_timestamp_ind(bahamas, enter_c5)
#enter_c5 = fpt.ds_timestamp_ind(bahamas, dropsondes, 49)
exit_c5  = fpt.ds_timestamp_ind(bahamas, dropsondes, 60)
print ('c5')
print ('----')
print (bahamas.heading[enter_c5])
print ('----')
print (exit_c5)
print (bahamas.heading[exit_c5])
print ('----')
exit_c5 = 26959
print (exit_c5)
print (bahamas.heading[exit_c5])
print ('----')

enter_c6_ds = fpt.ds_timestamp_ind(bahamas, dropsondes, 61)
enter_c6 = fpt.timestamp_ind_1min_prior(bahamas, enter_c6_ds) 
#exit_c6 = fpt.exit_circle_timestamp_ind(bahamas, enter_c6)
#enter_c6 = fpt.ds_timestamp_ind(bahamas, dropsondes, 61)
exit_c6  = fpt.ds_timestamp_ind(bahamas, dropsondes, 72)
print ('c6')
print ('----')
print (bahamas.heading[enter_c6])
print ('----')
print (exit_c6)
print (bahamas.heading[exit_c6])
print ('----')
exit_c6 = 31478 
print (exit_c6)
print (bahamas.heading[exit_c6])
print ('----')
headingdiff_c6 = bahamas['heading'][exit_c6]-bahamas['heading'][enter_c6]+360


#lidar_leg
bahamas["altitude_dt"] = (['time'], np.append(np.diff(bahamas["altitude"]),0))

min_dzdt_before_lidar_leg = fpt.min_timestamp_ind(bahamas, 'altitude_dt', 
                            slice('2020-02-13T16:45:00', '2020-02-13T17:00:00'), order=1000)

enter_lidar_leg = fpt.find_first_value_after_ts_ind(bahamas, 'altitude_dt', min_dzdt_before_lidar_leg, 0., 0.05)

min_dzdt_after_lidar_leg = fpt.min_timestamp_ind(bahamas, 'altitude_dt', 
                           slice('2020-02-13T17:00:00', '2020-02-13T17:10:00'), order=1000)

exit_lidar_leg = fpt.find_first_value_before_ts_ind(bahamas, 'altitude_dt', min_dzdt_after_lidar_leg, 0., 0.05)


ts_ind_list = [takeoff, 
               enter_c1, exit_c1, 
               enter_c2, exit_c2, 
               enter_c3, exit_c3,
               enter_leg1, exit_leg1,
               enter_radar_cal_wiggle,
               exit_radar_cal_wiggle,
               enter_leg2, exit_leg2,
               enter_c4, exit_c4, 
               enter_c5, exit_c5,
               enter_c6, exit_c6,
               enter_lidar_leg, exit_lidar_leg, 
               touchdown]
label_list = ["takeoff", 
              "enter_c1", "exit_c1", 
              "enter_c2", "exit_c2", 
              "enter_c3", "exit_c3", 
              "enter_leg1", "exit_leg1",
              "enter_radar_cal_wiggle",
              "exit_radar_cal_wiggle",
              "enter_leg2", "exit_leg2",
              "enter_c4", "exit_c4", 
              "enter_c5", "exit_c5",
              "enter_c6", "exit_c6",
              "enter_lidar_leg", "exit_lidar_leg", 
              "touchdown"]
# Out:
# c1
# ----
# <xarray.DataArray 'heading' ()>
# array(351.456085)
# Coordinates:
#     time     datetime64[ns] 2020-02-13T08:19:47.999996928
#     lat      float64 ...
#     lon      float64 ...
# Attributes:
#     units:      deg+
#     long_name:  heading
# ----
# <xarray.DataArray 'heading' ()>
# array(4763)
# <xarray.DataArray 'heading' ()>
# array(351.545593)
# Coordinates:
#     time     datetime64[ns] 2020-02-13T09:15:33.999993344
#     lat      float64 ...
#     lon      float64 ...
# Attributes:
#     units:      deg+
#     long_name:  heading
# ----
# 4769
# <xarray.DataArray 'heading' ()>
# array(352.239502)
# Coordinates:
#     time     datetime64[ns] 2020-02-13T09:15:40.000001024
#     lat      float64 ...
#     lon      float64 ...
# Attributes:
#     units:      deg+
#     long_name:  heading
# ----
# c2
# ----
# <xarray.DataArray 'heading' ()>
# array(112.268234)
# Coordinates:
#     time     datetime64[ns] 2020-02-13T09:28:33.999997184
#     lat      float64 ...
# ...

# %%
#create markers for every dropsonde
#--> helps to see the individual circles
#only execute if needed!
#ts_ind_list = []
#label_list = np.arange(1,len(dropsondes["launch_time"])+1)
#for i in range(len(dropsondes["launch_time"])):
#    ts_ind_list.append(fpt.ds_timestamp_ind(bahamas, dropsondes,  i))

# %% [markdown]
# # Create basic timeseries of bahamas data with markers for determined timestamps to manually evaluate the validity of the timestamps.

# %%
fig, ax = fpt.plot_bahamas_timeseries(bahamas, ts_ind_list, label_list)
#for a in ax:
#    a.set_xlim([datetime(2020, 2, 13, 12, 10, 0), datetime(2020, 2, 13, 12, 20, 0)])

# %% [markdown]
# # Create a ResearchFlight object to represent the flight meta data.

# %%
RF13 = ResearchFlight(name=f"RF{bahamas.attrs['flight_number']}",
                      mission=bahamas.attrs['mission'],
                      flight_id='HALO-0213',
                      contacts=[
                          {
                              'name': 'Marc Prange', 
                              'email': 'marc.prange@uni-hamburg.de',
                              'tags': ['lc','dp'],
                          },
                          {
                              'name': 'Lutz Hirsch', 
                              'email': 'lutz.hirsch@mpimet.mpg.de',
                              'tags': ['dp'],
                          },            
                          {
                              'name': 'Jessica Vial',
                              'email': 'jessica.vial@lmd.jussieu.fr',
                              'tags': ['flight PI']
                          }
                      ],
                      date=fpt.dt64_to_dt(bahamas['time'][takeoff].values).date(),
                      flight_report='https://observations.ipsl.fr/aeris/eurec4a-data/REPORTS/HALO/2020/20200213/HALO_0213.pdf',
                      takeoff=fpt.dt64_to_dt(bahamas['time'][takeoff].values),
                      landing=fpt.dt64_to_dt(bahamas['time'][touchdown].values),
                      events=[],
                      remarks=['Two standard circle sets (each 3 circles) with excursion to NTAS in between.',
                               'Radar calibration maneuver (20deg wiggle) flown at NTAS location.',
                               'At the beginning of the flight the circle area was dominated '
                               'by a flower cloud pattern with stratiform layers at ~2km.',
                               'During the flight the flower pattern collapsed slowly into a fish pattern.',
                               'During the whole flight precipitating cells were observed.',
                               'On the way to NTAS a few cold pools were observed with shallow sugar-type convection.'],
)

# %% [markdown]
# # Store the flight phase information in ResearchFlightSegment objects.

# %%
circling1 = ResearchFlightSegment(kinds=['circling'],
                                  name='circling 1',
                                  start=fpt.dt64_to_dt(bahamas["time"][enter_c1].values),
                                  end=fpt.dt64_to_dt(bahamas['time'][exit_c3].values),
                                  good_dropsondes=35,
                                  irregularities=[],
                                  segment_id='HALO-0213_o1',
                                 )
circle1 = ResearchFlightSegment(kinds=['circle'],
                                name='circle 1',
                                start=fpt.dt64_to_dt(bahamas["time"][enter_c1].values),
                                end=fpt.dt64_to_dt(bahamas['time'][exit_c1].values),
                                good_dropsondes=12,
                                irregularities=[],
                                segment_id='HALO-0213_c1',
                               )
circleBreak1to2 = ResearchFlightSegment(kinds=['circle_break'],
                                        name='circle break 1',
                                        start=fpt.dt64_to_dt(bahamas["time"][exit_c1].values),
                                        end=fpt.dt64_to_dt(bahamas['time'][enter_c2].values),
                                        irregularities=[],
                                        segment_id='HALO-0213_cb1',
                                       )
circle2 = ResearchFlightSegment(kinds=['circle'],
                                name='circle 2',
                                start=fpt.dt64_to_dt(bahamas["time"][enter_c2].values),
                                end=fpt.dt64_to_dt(bahamas['time'][exit_c2].values),
                                good_dropsondes=11,
                                irregularities=['Time to first sonde 61 sec.'],
                                segment_id='HALO-0213_c2',
                               )
circleBreak2to3 = ResearchFlightSegment(kinds=['circle_break'],
                                        name='circle break 2',
                                        start=fpt.dt64_to_dt(bahamas["time"][exit_c2].values),
                                        end=fpt.dt64_to_dt(bahamas['time'][enter_c3].values),
                                    irregularities=[],
                                    segment_id='HALO-0213_cb2',
                                       ) 
circle3 = ResearchFlightSegment(kinds=['circle'],
                                name='circle 3',
                                start=fpt.dt64_to_dt(bahamas["time"][enter_c3].values),
                                end=fpt.dt64_to_dt(bahamas['time'][exit_c3].values),
                                good_dropsondes=12,
                                irregularities=[],
                                segment_id='HALO-0213_c3',
                               )
leg1 = ResearchFlightSegment(kinds=['straight_leg'],
                             name='leg1 outbound NTAS',
                             start=fpt.dt64_to_dt(bahamas["time"][enter_leg1].values),
                             end=fpt.dt64_to_dt(bahamas['time'][exit_leg1].values),
                             irregularities=[],
                             segment_id='HALO-0213_sl1',
                            )
radar_cal_wiggle = ResearchFlightSegment(kinds=['radar_calibration_wiggle'],
                                         name='radar calibration wiggle',
                                         start=fpt.dt64_to_dt(bahamas["time"][enter_radar_cal_wiggle].values),
                                         end=fpt.dt64_to_dt(bahamas['time'][exit_radar_cal_wiggle].values),
                                         irregularities=[],
                                         segment_id='HALO-0213_rcw1',
                                        )
leg2 = ResearchFlightSegment(kinds=['straight_leg'],
                             name='leg2_inbound_NTAS',
                             start=fpt.dt64_to_dt(bahamas["time"][enter_leg2].values),
                             end=fpt.dt64_to_dt(bahamas['time'][exit_leg2].values),
                             irregularities=[],
                             segment_id='HALO-0213_sl2',
                            )
circling2 = ResearchFlightSegment(kinds=['circling'],
                                  name='circling 2',
                                  start=fpt.dt64_to_dt(bahamas["time"][enter_c4].values),
                                  end=fpt.dt64_to_dt(bahamas['time'][exit_c6].values),
                                  good_dropsondes=36,
                                  irregularities=[],
                                  segment_id='HALO-0213_o2',
                                 )
circle4 = ResearchFlightSegment(kinds=['circle'],
                                name='circle 4',
                                start=fpt.dt64_to_dt(bahamas["time"][enter_c4].values),
                                end=fpt.dt64_to_dt(bahamas['time'][exit_c4].values),
                                good_dropsondes=12,
                                irregularities=[],
                                segment_id='HALO-0213_c4',
                               )
circleBreak4to5 = ResearchFlightSegment(kinds=['circle_break'],
                                        name='circle break 4',
                                        start=fpt.dt64_to_dt(bahamas["time"][exit_c4].values),
                                        end=fpt.dt64_to_dt(bahamas['time'][enter_c5].values),
                                        irregularities=[],
                                        segment_id='HALO-0213_cb4',
                                       )
circle5 = ResearchFlightSegment(kinds=['circle'],
                                name='circle 5',
                                start=fpt.dt64_to_dt(bahamas["time"][enter_c5].values),
                                end=fpt.dt64_to_dt(bahamas['time'][exit_c5].values),
                                good_dropsondes=12,
                                irregularities=[],
                                segment_id='HALO-0213_c5',
                               )
circleBreak5to6 = ResearchFlightSegment(kinds=['circle_break'],
                                        name='circle break 5',
                                        start=fpt.dt64_to_dt(bahamas["time"][exit_c5].values),
                                        end=fpt.dt64_to_dt(bahamas['time'][enter_c6].values),
                                        irregularities=[],
                                        segment_id='HALO-0213_cb5',
                                       )
circle6 = ResearchFlightSegment(kinds=['circle'],
                                name='circle 6',
                                start=fpt.dt64_to_dt(bahamas["time"][enter_c6].values),
                                end=fpt.dt64_to_dt(bahamas['time'][exit_c6].values),
                                good_dropsondes=12,
                                irregularities=['Circle is only 357 deg'],
                                segment_id='HALO-0213_c6',
                               )
lidar_leg = ResearchFlightSegment(kinds=['lidar_leg'],
                                  name='lidar leg',
                                  start=fpt.dt64_to_dt(bahamas["time"][enter_lidar_leg].values),
                                  end=fpt.dt64_to_dt(bahamas['time'][exit_lidar_leg].values),
                                  irregularities=[],
                                  segment_id='HALO-0213_lc1',
                                 )

# %% [markdown]
# # Append the flight segments to the ResearchFlight object and save the object content to a .yaml file.

# %%
RF13.to_dictionary()
# Out:
# {'name': 'RF13',
#  'mission': 'EUREC4A',
#  'flight_id': 'HALO-0213',
#  'contacts': [{'name': 'Marc Prange',
#    'email': 'marc.prange@uni-hamburg.de',
#    'tags': ['lc', 'dp']},
#   {'name': 'Lutz Hirsch',
#    'email': 'lutz.hirsch@mpimet.mpg.de',
#    'tags': ['dp']},
#   {'name': 'Jessica Vial',
#    'email': 'jessica.vial@lmd.jussieu.fr',
#    'tags': ['flight PI']}],
#  'date': datetime.date(2020, 2, 13),
#  'flight_report': 'https://observations.ipsl.fr/aeris/eurec4a-data/REPORTS/HALO/2020/20200213/HALO_0213.pdf',
#  'takeoff': datetime.datetime(2020, 2, 13, 7, 56, 10),
#  'landing': datetime.datetime(2020, 2, 13, 17, 17, 17),
#  'events': [],
#  'remarks': ['Two standard circle sets (each 3 circles) with excursion to NTAS in between.',
#   'Radar calibration maneuver (20deg wiggle) flown at NTAS location.',
#   'At the beginning of the flight the circle area was dominated by a flower cloud pattern with stratiform layers at ~2km.',
# ...

# %%
RF13.append_segments([circling1,circle1, circleBreak1to2, 
                      circle2, circleBreak2to3,
                      circle3, 
                      leg1, radar_cal_wiggle, leg2,
                      circling2,circle4, circleBreak4to5,
                      circle5, circleBreak5to6,
                      circle6, lidar_leg])

# %%
RF13.to_yaml(filename='../flight_phase_files/HALO_RF13_20200213_info.yaml')
